# %%
import pandas as pd
from sklearn import tree
from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix

diabetes_df = pd.read_csv("../week_13/diabetes.csv")
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = diabetes_df.drop('Outcome', axis=1)
y = diabetes_df['Outcome']

# Split into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=42, stratify=y)

#Standardize
sc= StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
#estimator = model
rf = RandomForestClassifier(n_estimators=200,random_state=42)

rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7662337662337663

# %%
predictions = rf.predict(X_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       150
#            1       0.70      0.58      0.64        81
#
#     accuracy                           0.77       231
#    macro avg       0.75      0.72      0.73       231
# weighted avg       0.76      0.77      0.76       231

# %%
print(rf.feature_importances_, X.columns)
# Out:
# [0.09291691 0.265229   0.08982683 0.07090504 0.07509956 0.15354422
#  0.12056711 0.13191134] Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
#pull out a single tree
tree_10 = rf.estimators_[9]

# %%
import matplotlib.pyplot as plt

# Plot the decision tree model
fig = plt.figure(figsize=(30,30))

# Plot the decision tree
fig = tree.plot_tree(tree_10,
              filled=True)

# Save figure
plt.savefig("tree10.svg", dpi=200)

# Display figure
plt.show()

# %%
#XGBoost
from xgboost import XGBClassifier

#https://machinelearningmastery.com/install-xgboost-python-macos/
#https://brew.sh/
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# /var/folders/t2/8_yszszj5vz4xyg1fsy_1rlr0000gn/T/ipykernel_5030/1302162092.py in <module>
#       1 #XGBoost
# ----> 2 from xgboost import XGBClassifier
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/__init__.py in <module>
#       7 import os
#       8
# ----> 9 from .core import DMatrix, DeviceQuantileDMatrix, Booster, DataIter
#      10 from .training import train, cv
#      11 from . import rabit  # noqa
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/core.py in <module>
#     201
#     202 # load the XGBoost library globally
# --> 203 _LIB = _load_lib()
#     204
#     205
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/core.py in _load_lib()
#     179     if not lib_success:
#     180         libname = os.path.basename(lib_paths[0])
# --> 181         raise XGBoostError(
#     182             f"""
#     183 XGBoost Library ({libname}) could not be loaded.
#
# XGBoostError:
# XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed
#     - vcomp140.dll or libgomp-1.dll for Windows
#     - libomp.dylib for Mac OSX
#     - libgomp.so for Linux and other UNIX-like OSes
#     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#
#   * You are running 32-bit Python on a 64-bit OS
#
# Error message(s): ['dlopen(/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/lib/libxgboost.dylib, 6): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib\n  Referenced from: /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: image not found']

# %%
from sklearn.metrics import roc_curve, roc_auc_score

#ROC curve summarize the tradeoff between true positives and false positives
# ROC curves are the most appropriate for balanced datasets
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)
print(auc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/t2/8_yszszj5vz4xyg1fsy_1rlr0000gn/T/ipykernel_5030/1872801527.py in <module>
#       3 #ROC curve summarize the tradeoff between true positives and false positives
#       4 # ROC curves are the most appropriate for balanced datasets
# ----> 5 fpr, tpr, thresholds = roc_curve(y_test, y_pred)
#       6 auc = roc_auc_score(y_test, y_pred)
#       7 print(auc)
#
# NameError: name 'y_pred' is not defined

# %%
#precision recall curve summarizes the trade-off between true positive rates
# and positive values. these are best for imbalance datasets

from sklearn.metrics import precision_recall_curve, f1_score, auc

precision, recall, thresholds = precision_recall_curve(y_test, y_pred)
f1=f1_score(y_test, y_pred)
print(f1)

# %%
pr_auc = auc(recall, precision)
print(pr_auc)
