# %% [markdown]
# ## Warm Up

# %%
import pandas as pd

df = pd.read_csv('loans_full_schema.csv')
df.head()
# Out:
#                  emp_title  emp_length state homeownership  annual_income  \
# 0  global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1   warehouse office clerk        10.0    HI          RENT        40000.0
# 2                 assembly         3.0    WI          RENT        40000.0
# 3         customer service         1.0    PA          RENT        30000.0
# 4     security supervisor         10.0    CA          RENT        35000.0
#
#    verified_income  debt_to_income  annual_income_joint  \
# 0         Verified           18.01                  NaN
# 1     Not Verified            5.04                  NaN
# 2  Source Verified           21.15                  NaN
# 3     Not Verified           10.16                  NaN
# 4         Verified           57.96              57000.0
#
#   verification_income_joint  debt_to_income_joint  ...  sub_grade  \
# 0                       NaN                   NaN  ...         C3
# ...

# %% [markdown]
# ## Lambda
# - Lambda functions is an anonymous function which means, it doesn't have a name
# - have less code than a normal function
#
# Use lambda as function (starts with def), to filter results, apply results to a column or row, call a more complicated function, etc.

# %%
jeopardy_df = pd.read_csv("JEOPARDY_CSV.csv")
jeopardy_df.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  12/31/2004  Jeopardy!                          HISTORY  $200
# 1         4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  12/31/2004  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jeopardy_df.columns = jeopardy_df.columns.str.replace(" ", "")
jeopardy_df.head()
# Out:
#    ShowNumber     AirDate      Round                         Category  Value  \
# 0        4680  12/31/2004  Jeopardy!                          HISTORY  $200
# 1        4680  12/31/2004  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2        4680  12/31/2004  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3        4680  12/31/2004  Jeopardy!                 THE COMPANY LINE  $200
# 4        4680  12/31/2004  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jeopardy_df.dtypes
# Out:
# ShowNumber     int64
# AirDate       object
# Round         object
# Category      object
# Value         object
# Question      object
# Answer        object
# dtype: object

# %%
jeopardy_df['AirDate']=pd.to_datetime(jeopardy_df['AirDate'], format='%m/%d/%Y')
jeopardy_df
# Out:
#         ShowNumber    AirDate             Round  \
# 0             4680 2004-12-31         Jeopardy!
# 1             4680 2004-12-31         Jeopardy!
# 2             4680 2004-12-31         Jeopardy!
# 3             4680 2004-12-31         Jeopardy!
# 4             4680 2004-12-31         Jeopardy!
# ...            ...        ...               ...
# 216925        4999 2006-05-11  Double Jeopardy!
# 216926        4999 2006-05-11  Double Jeopardy!
# 216927        4999 2006-05-11  Double Jeopardy!
# 216928        4999 2006-05-11  Double Jeopardy!
# 216929        4999 2006-05-11   Final Jeopardy!
#
#                                Category    Value  \
# 0                               HISTORY    $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES    $200
# 2           EVERYBODY TALKS ABOUT IT...    $200
# 3                      THE COMPANY LINE    $200
# 4                   EPITAPHS & TRIBUTES    $200
# ...                                 ...      ...
# ...

# %%
jeopardy_df = jeopardy_df.assign(month=lambda x: x['AirDate'].dt.month)
jeopardy_df.head()
# Out:
#    ShowNumber    AirDate      Round                         Category  Value  \
# 0        4680 2004-12-31  Jeopardy!                          HISTORY  $200
# 1        4680 2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2        4680 2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3        4680 2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4        4680 2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                             Question      Answer  month
# 0  For the last 8 years of his life, Galileo was ...  Copernicus     12
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe     12
# 2  The city of Yuma in this state has a record av...     Arizona     12
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's     12
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams     12

# %%
jeopardy_df['month2'] = jeopardy_df.apply(month=lambda x: x['AirDate'].dt.month, axis=1)
jeopardy_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/t2/8_yszszj5vz4xyg1fsy_1rlr0000gn/T/ipykernel_1694/1055921957.py in <module>
# ----> 1 jeopardy_df['month2'] = jeopardy_df.apply(month=lambda x: x['AirDate'].dt.month, axis=1)
#       2 jeopardy_df.head()
#
# TypeError: apply() missing 1 required positional argument: 'func'

# %% [markdown]
# # Filter
# -use lambda to filter

# %%
value_list = jeopardy_df['Value'].tolist()
value_list=value_list[0:50]
value_list

#goal = want a  list of all values greater than 300
# Out:
# ['$200 ',
#  '$200 ',
#  '$200 ',
#  '$200 ',
#  '$200 ',
#  '$200 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$2,000 ',
#  '$800 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$1,200 ',
#  '$2,000 ',
#  '$1,200 ',
#  '$1,200 ',
#  '$1,200 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ']

# %%
# clean the data:  $, commas, spaces
# can ither inlcue all logic in the  lambda , or replace the characters we dont want adn then run the lambda to filter
clean_up_lambda=lambda num:int(num.replace('$','').replace(' ','').replace(',',''))

filtered_list = list(filter(lambda num:int(num.replace('$','').replace(' ','').replace(',',''))>300, value_list))
filtered_list
# Out:
# ['$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$600 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$2,000 ',
#  '$800 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$1,000 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$400 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$800 ',
#  '$1,200 ',
#  '$2,000 ',
#  '$1,200 ',
#  '$1,200 ',
#  '$1,200 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ',
#  '$1,600 ']

# %% [markdown]
# # Map and Reduce
#
# Map allows us to apply a function over all the input values. It allows use to iterate over various sizes of inputs: whole dataframe, column, list
#
# Reduce performs a computation or aggregation over the whole list.

# %%
mapped_list = list(map(lambda num:int(num.replace('$','').replace(' ','').replace(',',''))>300, value_list))
mapped_list
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]
